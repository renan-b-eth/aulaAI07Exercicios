# %%
# !pip install pandas matplotlib seaborn

# %% [markdown]
# ### 1. Preparar o ambiente
#
# Instalar e importar pips
#
# !pip install pandas matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as pyplot
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
df = pd.read_csv("./survey.csv")

# %%
df.sample()
# Out:
#                                  user_id language platform gender  age  q1  \
# 68  cb71d11a-4e8d-4ab8-80be-ac1f46f5b2d1       en      NaN   male  1.0 NaN
#
#      q2   q3   q4   q5  ...  q17  q18  q19  q20  q21  q22  q23  q24  q25  q26
# 68  9.0  9.0  9.0  7.0  ...  9.0  6.0  7.0  8.0  8.0  9.0  5.0  5.0  7.0  5.0
#
# [1 rows x 31 columns]

# %%
df.shape # dimensoes do cvs linha / coluna
# Out:
# (80, 31)

# %% [markdown]
# ### limpeza de dados
#
# 1. Tratar dados faltantes (remover/preencher)
# 2. remover dados duplicados
# 3. remover colunas poucos informativas

# %%
df.tail()
# Out:
#    user_id language platform gender  age  q1  q2  q3  q4  q5  ...  q17  q18  \
# 75     NaN      NaN      NaN    NaN  NaN NaN NaN NaN NaN NaN  ...  NaN  NaN
# 76     NaN      NaN      NaN    NaN  NaN NaN NaN NaN NaN NaN  ...  NaN  NaN
# 77     NaN      NaN      NaN    NaN  NaN NaN NaN NaN NaN NaN  ...  NaN  NaN
# 78     NaN      NaN      NaN    NaN  NaN NaN NaN NaN NaN NaN  ...  NaN  NaN
# 79     NaN      NaN      NaN    NaN  NaN NaN NaN NaN NaN NaN  ...  NaN  NaN
#
#     q19  q20  q21  q22  q23  q24  q25  q26
# 75  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 76  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 77  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 79  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 31 columns]

# %%
df.info() # informacao das colunas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 31 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   74 non-null     object
#  1   language  74 non-null     object
#  2   platform  66 non-null     object
#  3   gender    74 non-null     object
#  4   age       75 non-null     float64
#  5   q1        74 non-null     float64
#  6   q2        75 non-null     float64
#  7   q3        75 non-null     float64
#  8   q4        75 non-null     float64
#  9   q5        74 non-null     float64
#  10  q6        75 non-null     float64
#  11  q7        75 non-null     float64
#  12  q8        75 non-null     float64
#  13  q9        75 non-null     float64
#  14  q10       74 non-null     float64
#  15  q11       75 non-null     float64
#  16  q12       75 non-null     float64
#  17  q13       75 non-null     float64
#  18  q14       74 non-null     float64
# ...

# %%
df2 = df.notna() # precisa salvar numa nova variavel
# ou df.dropna(inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 31 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   80 non-null     bool
#  1   language  80 non-null     bool
#  2   platform  80 non-null     bool
#  3   gender    80 non-null     bool
#  4   age       80 non-null     bool
#  5   q1        80 non-null     bool
#  6   q2        80 non-null     bool
#  7   q3        80 non-null     bool
#  8   q4        80 non-null     bool
#  9   q5        80 non-null     bool
#  10  q6        80 non-null     bool
#  11  q7        80 non-null     bool
#  12  q8        80 non-null     bool
#  13  q9        80 non-null     bool
#  14  q10       80 non-null     bool
#  15  q11       80 non-null     bool
#  16  q12       80 non-null     bool
#  17  q13       80 non-null     bool
#  18  q14       80 non-null     bool
#  19  q15       80 non-null     bool
#  20  q16       80 non-null     bool
# ...

# %%
df.dropna(how="all")
# Out:
#                                  user_id language platform  gender   age  \
# 0   080c468b-27c0-455c-aa63-b8f807f2e3d7       en  Desktop    male  34.0
# 1   0b0379c7-04db-4c85-84bd-a2bd55329e29       en   Mobile  female  19.0
# 2   0e623280-b28b-4d4a-8eea-0732f09ed497       en   Mobile  female  19.0
# 3   045dc0f3-a730-4d03-a615-f51814e5b04f       en   Mobile    male  21.0
# 4   092f2ee7-5281-4a09-9bce-e5523b95b53b       en      NaN  female  53.0
# ..                                   ...      ...      ...     ...   ...
# 70  f3b94dcb-2dde-48d7-968d-606fcddd692d       en  Desktop    male  46.0
# 71  ddbc5616-edb8-4052-9186-6e105e4491f6       en   Mobile    male  20.0
# 72  a7788435-7465-4f4d-9f4f-d412db68b295       en   Mobile  female  18.0
# 73  a7788435-7465-4f4d-9f4f-d412db68b295       en   Mobile  female  18.0
# 74  a7788435-7465-4f4d-9f4f-d412db68b295       en   Mobile  female  18.0
#
#       q1    q2    q3    q4    q5  ...   q17   q18   q19   q20   q21   q22  \
# ...

# %%
df2_semduplicados = df2.drop_duplicates()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 31 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   80 non-null     bool
#  1   language  80 non-null     bool
#  2   platform  80 non-null     bool
#  3   gender    80 non-null     bool
#  4   age       80 non-null     bool
#  5   q1        80 non-null     bool
#  6   q2        80 non-null     bool
#  7   q3        80 non-null     bool
#  8   q4        80 non-null     bool
#  9   q5        80 non-null     bool
#  10  q6        80 non-null     bool
#  11  q7        80 non-null     bool
#  12  q8        80 non-null     bool
#  13  q9        80 non-null     bool
#  14  q10       80 non-null     bool
#  15  q11       80 non-null     bool
#  16  q12       80 non-null     bool
#  17  q13       80 non-null     bool
#  18  q14       80 non-null     bool
#  19  q15       80 non-null     bool
#  20  q16       80 non-null     bool
# ...

# %%
df2.drop("user_id", axis=1)

df2.drop(5, axis=0) # linha 5 do axis 0 que é linha
# Out:
#     user_id  language  platform  gender    age     q1     q2     q3     q4  \
# 0      True      True      True    True   True   True   True   True   True
# 1      True      True      True    True   True   True   True   True   True
# 2      True      True      True    True   True   True   True   True   True
# 3      True      True      True    True   True   True   True   True   True
# 4      True      True     False    True   True   True   True   True   True
# ..      ...       ...       ...     ...    ...    ...    ...    ...    ...
# 75    False     False     False   False  False  False  False  False  False
# 76    False     False     False   False  False  False  False  False  False
# 77    False     False     False   False  False  False  False  False  False
# 78    False     False     False   False  False  False  False  False  False
# 79    False     False     False   False  False  False  False  False  False
#
# ...

# %%
df3 = pd.read_csv("./survey.csv").dropna().drop_duplicates().drop("user_id", axis=1)

# %%
df3
# Out:
#    language platform  gender   age    q1    q2    q3    q4    q5    q6  ...  \
# 0        en  Desktop    male  34.0   9.0   7.0   6.0   6.0   7.0   7.0  ...
# 1        en   Mobile  female  19.0  10.0  10.0  10.0   9.0  10.0  10.0  ...
# 2        en   Mobile  female  19.0  10.0  10.0  10.0  10.0  10.0  10.0  ...
# 3        en   Mobile    male  21.0   5.0   8.0   5.0   5.0   5.0   5.0  ...
# 5        en   Mobile  female  53.0  10.0   9.0   9.0   9.0   5.0   6.0  ...
# 7        en   Mobile  female  20.0   9.0   5.0  10.0   6.0   8.0  10.0  ...
# 8        en   Mobile  female  19.0   8.0   8.0  10.0   9.0   9.0   8.0  ...
# 9        en   Mobile    male  19.0   7.0   8.0   4.0   7.0   8.0   9.0  ...
# 10       en   Mobile  female  13.0   9.0   9.0  10.0   8.0  10.0   9.0  ...
# 11       en   Mobile    male  18.0  10.0  10.0  10.0  10.0  10.0  10.0  ...
# 12       en   Mobile  female  19.0  10.0  10.0   9.0   8.0   8.0   8.0  ...
# ...

# %% [markdown]
# ### 4. Estatatistica "Descritivas"
